# %% [markdown]
# **MULITIPLE LINEAR REGRESSION**

# %%
# House price predication

import numpy as np
import pandas as pd

np.random.seed(42)

area =np.random.randint(500,3000,100)
bedrooms =np.random.randint(1,6,100)
age =np.random.randint(1,40,100)

price = (area*0.05)+(bedrooms*5)+(age*0.3)+ np.random.normal(0,10,100)

Data = pd.DataFrame({
    "area":area,
    "bedrooms":bedrooms,
    "age":age,
    "price":price.round(2)
})
Data.to_csv("House_price.csv",index=False)

# %%
df=Data
df.head(5)
# Out:
#    area  bedrooms  age   price
# 0  1360         2    9   71.20
# 1  1794         1    6   90.53
# 2  1630         5   16  110.19
# 3  1595         3   29   85.96
# 4  2138         4    3  114.39

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X=df[["area","bedrooms","age"]]   #df.drop("price",axis=1)
Y=df["price"]

X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2,random_state=1)

model =LinearRegression()

model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
House =[[1794,1,6]]

result =model.predict(House)

print("predicted price :",result)
# Out:
# predicted price : [99.58845735]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
Y_pred =model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, root_mean_squared_error, r2_score

print("MAE :",mean_absolute_error(Y_test,Y_pred))
print("MSE :",mean_squared_error(Y_test,Y_pred))
print("RMSE :",root_mean_squared_error(Y_test,Y_pred))
print("R2_SCORE :",r2_score(Y_test,Y_pred))
# Out:
# MAE : 8.475063011143005
# MSE : 99.70992162026869
# RMSE : 9.985485547546935
# R2_SCORE : 0.9339160610261832

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5,4))
sns.kdeplot(Y_test,label="ACTUAL PRIZE",shade=True)
sns.kdeplot(Y_pred,label="PREDICTED PRIZE",shade=True)
plt.title ("DIDTRIBUTION : ACTUAL PRIZE VS PREDICTED PRIZE")
plt.xlabel("Score")
plt.ylabel("DENSITY")
plt.legend()
plt.show()
# Out:
# /tmp/ipython-input-1419229689.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(Y_test,label="ACTUAL PRIZE",shade=True)
# /tmp/ipython-input-1419229689.py:6: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(Y_pred,label="PREDICTED PRIZE",shade=True)

# %%
plt.figure(figsize=(5,4))
plt.scatter(range(len(Y_test)),Y_test.values)
plt.plot(range(len(Y_pred)),Y_pred)
plt.title (" ACTUAL PRIZE VS PREDICTED LINE CHART")
plt.xlabel("INDEX")
plt.ylabel("PRICE")
plt.legend(["ACTUAL PRICE","PREDICITED PRICE"])
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.scatterplot(x=Y_test,y=Y_pred)
plt.plot([Y_test.min(),Y_pred.max()],[Y_test.min(),Y_pred.max()],'r--')
plt.title (" REGRESSION LINE CHART")
plt.xlabel("ACTUAL PRIZE")
plt.ylabel("PREDICTED PRICE")
plt.grid(True)
plt.show()

# %% [markdown]
# **SIMPLE LINEAR REGRESSION**

# %%
import numpy as np
import pandas as pd

np.random.seed(50)

area =np.random.randint(500,3000,100)
bedrooms =np.random.randint(1,6,100)
age =np.random.randint(1,40,100)

price = (area*0.05)+(bedrooms*5)+(age*0.3)+ np.random.normal(0,10,100)

Data = pd.DataFrame({
    "area":area,
    "bedrooms":bedrooms,
    "age":age,
    "price":price.round(2)
})
Data.to_csv(" Simple_House_price.csv",index=False)

# %%
df=Data
df.head(6)
# Out:
#    area  bedrooms  age   price
# 0  2212         4   22  135.10
# 1  2004         4   15  120.84
# 2  2431         3   20  140.46
# 3  2657         4   17  164.98
# 4  2514         1   34  140.76
# 5   632         1   20   32.85

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X=df[["area"]]   #df.drop("price",axis=1)
Y=df["price"]

X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2,random_state=50)

model =LinearRegression()

model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
House =[[2212]]

result =model.predict(House)

print("predicted price :",result)
# Out:
# predicted price : [133.32372959]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, root_mean_squared_error, r2_score

print("MAE :",mean_absolute_error(Y_test,Y_pred))
print("MSE :",mean_squared_error(Y_test,Y_pred))
print("RMSE :",root_mean_squared_error(Y_test,Y_pred))
print("R2_SCORE :",r2_score(Y_test,Y_pred))
# Out:
# MAE : 30.55740780486037
# MSE : 1470.6817138263496
# RMSE : 38.349468233944904
# R2_SCORE : -0.5414003915490226

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5,4))
sns.kdeplot(Y_test,label="ACTUAL PRIZE",shade=True)
sns.kdeplot(Y_pred,label="PREDICTED PRIZE",shade=True)
plt.title ("DIDTRIBUTION : ACTUAL PRIZE VS PREDICTED PRIZE")
plt.xlabel("Score")
plt.ylabel("DENSITY")
plt.legend()
plt.show()
# Out:
# /tmp/ipython-input-1419229689.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(Y_test,label="ACTUAL PRIZE",shade=True)
# /tmp/ipython-input-1419229689.py:6: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(Y_pred,label="PREDICTED PRIZE",shade=True)

# %%
plt.figure(figsize=(5,4))
plt.scatter(range(len(Y_test)),Y_test.values)
plt.plot(range(len(Y_pred)),Y_pred)
plt.title (" ACTUAL PRIZE VS PREDICTED LINE CHART")
plt.xlabel("INDEX")
plt.ylabel("PRICE")
plt.legend(["ACTUAL PRICE","PREDICITED PRICE"])
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.scatterplot(x=Y_test,y=Y_pred)
plt.plot([Y_test.min(),Y_pred.max()],[Y_test.min(),Y_pred.max()],'r--')
plt.title (" REGRESSION LINE CHART")
plt.xlabel("ACTUAL PRIZE")
plt.ylabel("PREDICTED PRICE")
plt.grid(True)
plt.show()

# %% [markdown]
# POLYNOMIAL REGRESSION

# %%
df3=Data
df3.head()
# Out:
#    area  bedrooms  age   price
# 0  2212         4   22  135.10
# 1  2004         4   15  120.84
# 2  2431         3   20  140.46
# 3  2657         4   17  164.98
# 4  2514         1   34  140.76

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures

X=df[["age"]]    # df.drop("price",axis=1)   LINEAR REGRESSION - MULTIPLE
Y=df["price"]

poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

model = LinearRegression()

model.fit(X_poly,Y)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X_poly)

# %%
print("R2 SCORE : ",r2_score(Y,Y_pred))
# Out:
# R2 SCORE :  0.0324830774830559

# %%
area_range = np.linspace(X.min(),X.max(),100).reshape(-1,1)
area_range_poly = poly.transform(area_range)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(

# %%
curve = model.predict(area_range_poly)

plt.figure(figsize=(5,4))
plt.scatter(X,Y)
plt.plot(area_range,curve)

plt.xlabel("AREA")
plt.ylabel("price")
plt.title("POLYNOMIAL REGRESSION LINE")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /tmp/ipython-input-3712932934.py:10: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
